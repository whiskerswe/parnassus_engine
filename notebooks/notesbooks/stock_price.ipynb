# %%
import numpy as np

# %%
file = '../data/source/AAPL_stock_price_example.csv'
input_stock_price_array = np.genfromtxt(file, delimiter=',', names=True, usecols=(1))

# %%
input_stock_price_array.size
# Out:
# 229

# %%
sorted_input_stock_price_array = np.sort(input_stock_price_array)[::1]

# %%
print("Sorted stock price array in order of day traded", sorted_input_stock_price_array[:5])
# Out:
# Sorted stock price array in order of day traded [(142.190002,) (147.929993,) (148.259995,) (150.      ,) (150.75    ,)]
