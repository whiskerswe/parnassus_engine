# %%
# f = open("../data/source/evolution_of_data_analysis_comma.csv","r", encoding='utf8')
# print(f.read())
# f.close()

# %%
import numpy as np

# %%
my_first_array = np.array([1, 2, 3])
print(my_first_array)
# my_first_array.shape
# len(my_first_array)
# my_first_array.dtype.name
# my_first_array.astype(int)
my_first_array.astype(np.int64)
my_first_array.sum()
my_first_array.min()
my_first_array.max()
my_first_array.mean()
# Out:
# [1 2 3]
# np.float64(2.0)

# %% [raw]
# To ensure the project is platform independent and reproducible, it is adviseable to set type.
# Consider using np.int32 as I might have a lot of data, but the data ranges should not be very big.
